# %% [markdown]
# <div style="border:solid black 2px; padding: 20px"><h1 style="color:black; margin-bottom:20px">Reviewer's comment v1</h1>
# Halo Kak !
#
# Perkenalkan saya Dipta, disini saya akan mereview tugas Kakak ya.
#
# Saya akan memberikan beberapa komen seperti dibawah ini, tolong jangan dipindah, dirubah, maupun dihapus ya.
#
# Komen yang saya berikan akan muncul dalam warna hijau, kuning, atau pun merah seperti ini:
#
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>
#
# <div class="alert alert-warning">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Terdapat beberapa catatan.
#
# </div>
#
# <div class="alert alert-danger">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Perlu beberapa perbaikan
#
# </div>
#
# Dan tentu saja Kakak dapat menjawab saya dengan menggunakan ini
#
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak
# </div>

# %% [markdown]
# # Analisis Game Berpotensial Ice
#
# Anda bekerja di toko daring "Ice" yang menjual video game dari seluruh dunia. Data terkait ulasan pengguna dan ahli game, genre, platform (misalnya Xbox atau PlayStation), dan data historis penjualan game tersedia dari sumber terbuka. Anda perlu mengidentifikasi pola-pola yang menentukan apakah suatu game dapat dikatakan berhasil atau tidak. Dengan begitu, Anda bisa menemukan game yang paling berpotensial dan merencanakan kampanye iklannya.

# %% [markdown]
# ## Tujuan
#
# Proyek ini berfokus pada analisis penjualan game. Data dilakukan pre-processing untuk membersihkan dan merapihkan data agar dapat diolah. Selanjutnya dilakukan Exploratory Data Analysis (EDA) dan Data Visualization untuk mengetahui oulier dan insight dari data. Dan terakhir dilakukan analisis data statistik untuk Hypothesis Testing. Data ini diambil pada Desember 2016. Hasil analisis akan memungkinkan untuk membangun acuan bagi tahun 2017.

# %% [markdown]
# ### Hipotesis
#
# 1. Rata-rata rating pengguna platform Xbox One dan PC adalah sama.
# 2. Rata-rata rating pengguna genre Action dan Sports berbeda.

# %% [markdown]
# ### Tahapan
#
# Data tentang hasil ulasan game disimpan dalam file `/datasets/games_us.csv`. Tidak ada informasi terkait kualitas data tersebut, sehingga perlu dilakukan pemeriksaan terlebih dahulu sebelum menguji hipotesis.
#
# Proyek ini terdiri dari tiga tahap:
#
# 1. Pra-pemrosesan Data
# 2. Analisis Data Exploratif (EDA)
# 3. Analisis Data Statistik (Hyphothesis Testing)

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ## 1. Pra-pemrosesan Data

# %%
# Import library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 1.1. Memuat Data

# %%
# Try and except datasets
try:
    data = pd.read_csv('games.csv')
except:
    data = pd.read_csv('/datasets/games.csv') 

data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 1.2. Mengeksplorasi Data Awal

# %%
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# **Deskripsi data**:
#
#
# - `Name` — nama game
# - `Platform` — nama platform game dapat dimainkan
# - `Genre` — jenis game
# - `NA_sales`  — penjualan di Amerika Utara dalam satuan juta USD
# - `EU_sales` — penjualan di Eropa dalam satuan juta USD
# - `JP_sales` — penjualan di Jepang dalam satuan juta USD
# - `Other_sales` — penjualan di negara lainnya dalam satuan juta USD
# - `Critic_Score` — skor ulasan dari kritikus, maksimal 100
# - `User_Score` — skor ulasan dari pengguna, maksimal 10
# - `Rating` — Entertainment Software Rating Board (ESRB)

# %%
# Check data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Nama kolom tidak huruf kecil.
# * Terlihat ada beberapa nilai yang hilang.
# * Kolom `Year_of_Release` akan terlihat lebih rapih apabila menggunakan integer.

# %%
# Check total missing values descending
data.isna().sum().sort_values(ascending=False)
# Out:
# Critic_Score       8578
# Rating             6766
# User_Score         6701
# Year_of_Release     269
# Name                  2
# Genre                 2
# Platform              0
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# dtype: int64

# %%
# Check unique data from 'User_Score' column
data['User_Score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
# Check duplicated data
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Kolom `Critic_Score`, `Rating`, `User_Score`, `Year_of_Release`, `Name` dan  `Genre` terdapat nilai hilang yang perlu dianalisis.
# * Kolom `User_Score` terdapat nilai TBD yang merupakan anomali sehingga perlu dianalisis lebih dalam.
# * Dataset tidak memiliki duplikat pada datanya.

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %%
# Calculating some statistical data 
data.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Kolom sales terdapat nilai yang tidak wajar, yaitu min sales dan 25% sales adalah 0.000000 sehingga perlu dianalisis.

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### Kesimpulan dan Langkah-Langkah Selanjutnya
#
# #### **Gaya Penulisan Judul**
#
# Judul kolom memiliki huruf besar dan kecil. Untuk mempermudah analisis, nama kolom akan diubah menjadi huruf kecil.
#
# #### **Nilai yang Hilang**
#
# Setiap baris dalam tabel menyimpan data terkait penjualan game yang telah terjual. Sejumlah kolom menyimpan data yang mendeskripsikan game itu sendiri: tahun rilis, platform yang digunakan, dan tipe game. Sisanya menyimpan data terkait informasi game terjual beserta penilaiannya: Penjualan di Amerika, Eropa, Jepang dan negara-negara lain, nilai ulasan kritikus dan pengguna, serta Rating game tersebut.
#
# Jelas bahwa data yang kita miliki cukup untuk menguji hipotesis. Meski demikian, kita memiliki nilai-nilai yang hilang.
#
# * Setiap nilai hilang akan diperiksa terlebih dahulu persentase terhadap keseluruhan data. Kemudian akan diperiksa berpola atau tidak, untuk mengatasi tindakan apa yang perlu dilakukan untuk mengatasi nilai hilang tersebut.
#
# Alasan mengapa data tersebut hilang sangatlah berguna untuk mempelajari dan mencoba memperbaikinya namun sayangnya, kita belum memiliki kesempatan tersebut dalam proyek ini.
#
# #### **Gaya Penulisan**
#
# Setelah mengatasi nilai-nilai yang hilang, langkah selanjutnya yaitu merapihkan data:
#
# * Mengubah nilai pada kolom `Year_of Release` menjadi integer.
# * Membuat kolom baru untuk menghitung total penjualan (jumlah penjualan di semua wilayah) untuk tiap game.
#
# #### **Duplikat**
#
# Selanjutnya memeriksa duplikat pada data. Namun, pada dataset ini tidak memiliki data duplikat pada data. Sehingga tidak perlu dilakukan analisis duplikat awal.
#
# #### **Anomali Data**
#
# Setelah memeriksa data duplikat perlu memepertimbangkan data anomali berikut, karena data tersebut mempengaruhi analisis penelitian.
#
# * Pada kolom `User_Score` terdapat nilai yang tidak wajar, yaitu TBD.

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 1.3. Memperbaiki Penulisan Judul

# %%
# Check the name of columns
data.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %%
# Renaming the columns
data = data.rename(columns=str.lower)

# %%
# checking columns
data.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 1.4. Mengatasi Nilai-Nilai yang Hilang

# %%
# Check total missing values descending
data.isna().sum().sort_values(ascending=False)
# Out:
# critic_score       8578
# rating             6766
# user_score         6701
# year_of_release     269
# name                  2
# genre                 2
# platform              0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# dtype: int64

# %% [markdown]
# **Langkah pertama** dalam menangani nilai-nilai yang hilang yaitu menghitung persentasenya serta dibandingkan dengan keseluruhan data untuk mengetahui dampak dari nilai-nilai yang hilang tersebut terhadap dataset.

# %%
# Loop for checking the percentage of missing values per total values each column
for col in data.columns:
    missing = data[col].isnull().sum()
    total = data[col].shape[0]
    percent = (missing/total) * 100
    print(f"Kolom {col}: {percent:.2f}% nilai yang hilang.")
# Out:
# Kolom name: 0.01% nilai yang hilang.
# Kolom platform: 0.00% nilai yang hilang.
# Kolom year_of_release: 1.61% nilai yang hilang.
# Kolom genre: 0.01% nilai yang hilang.
# Kolom na_sales: 0.00% nilai yang hilang.
# Kolom eu_sales: 0.00% nilai yang hilang.
# Kolom jp_sales: 0.00% nilai yang hilang.
# Kolom other_sales: 0.00% nilai yang hilang.
# Kolom critic_score: 51.32% nilai yang hilang.
# Kolom user_score: 40.09% nilai yang hilang.
# Kolom rating: 40.48% nilai yang hilang.

# %% [markdown]
# **Kesimpulan sementara:**
#
# Dalam beberapa situasi, nilai yang hilang jika bagiannya tidak banyak (katakanlah, 5-10%), nilai tersebut dapat dihapus.
#
# Pada kasus ini nilai pada kolom name, dan genre bisa di hapus.

# %%
# Remove missing data in name and genre column
data = data.dropna(subset=['name', 'genre']).reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# Untuk kasus year, bisa diisi dengan median data.

# %%
# Fill missing value in year_of_release with median
median_year_platform = data.groupby('platform')['year_of_release'].median()

# %%
# Apply to dataframe
data['year_of_release'] = data.apply(lambda x: median_year_platform[x.platform] if
                                     pd.isna(x.year_of_release) else x.year_of_release, axis = 1)

# %% [markdown]
# <div class="alert alert-warning">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - bisa juga diisi dengan 0
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak, terimakasih sarannya. Tapi saya mengikuti yang diajarkan Kak David di sesi QnA saja...
# </div>

# %%
# Check total missing values descending
data.isna().sum().sort_values(ascending=False)
# Out:
# critic_score       8576
# rating             6764
# user_score         6699
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# dtype: int64

# %% [markdown]
# **Langkah kedua** dalam menangani nilai-nilai yang hilang yaitu:
#
#
# 1. Jika kategoris maka ditentukan apakah nilai yang hilang memiliki suatu pola.
# * Jika nilainya tidak terdapat pola, nilai tersebut dapat diganti dengan nilai default, seperti string kosong atau kata tertentu.
# * Jika berpola, maka perlu analisis lebih lanjut.
#
#
# 2. Jika kuantitatif maka ditentukan apakah data memiliki outlier yang signifikan.
# * Jika tidak terdapat outlier yang signifikan, nilai tersebut dapat dihitung rata-rata data pada kolom atau seluruh dataset.
# * Jika data memiliki oulier yang signifikan, nilai tersebut dapat dihitung median data pada kolom atau seluruh dataset.

# %%
# Function for checking missing pattern
def check_missing_pattern(data):
    
    missing_pattern = {}
    
    for col in data.columns:
        # Create a boolean mask to identify missing values
        mask = data[col].isnull()
        # Get sum of missing values
        missing = data[col].isnull().sum()
        
        # If there are no missing values, the pattern is "none"
        if missing == 0:
            missing_pattern[col] = "none"
        # If there is a missing value, check if there is a pattern
        else:
            # Create a boolean mask to identify non-missing values
            mask_not_missing = ~mask
            # Count the number of unique values in a column
            unique_values = data[col].nunique()
            # If there are fewer unique values than missing values, the pattern is "random"
            if unique_values < missing:
                missing_pattern[col] = "random"
            # Otherwise, the pattern is "pattern"
            else:
                missing_pattern[col] = "pattern"
    
    return missing_pattern

# %%
# Check the missing pattern
missing_pattern = check_missing_pattern(data)
print(missing_pattern)
# Out:
# {'name': 'none', 'platform': 'none', 'year_of_release': 'none', 'genre': 'none', 'na_sales': 'none', 'eu_sales': 'none', 'jp_sales': 'none', 'other_sales': 'none', 'critic_score': 'random', 'user_score': 'random', 'rating': 'random'}

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Kolom `critic_score` memiliki nilai hilang yang tidak berpola.
# * Kolom `user_score` memiliki nilai hilang yang tidak berpola.
# * Kolom `rating` memiliki nilai hilang yang tidak berpola.
#
# Karena merupakan variabel katagoris. Nilai hilang pada kolom critic_score dan user_score tidak masalah memiliki nilai hilang. Sedangkan nilai tbd pada user_score akan dianggap sama dengan nilai hilang. Untuk data pada rating akan diisi dengan unidentified

# %%
# Filling the missing values with fillna()
data['user_score'] = data['user_score'].replace('tbd', np.nan).astype('float')

# %%
# Filling the missing values with fillna()
data['rating'] = data['rating'].fillna('unidentified')

# %%
# Check total missing values descending
data.isna().sum().sort_values(ascending=False)
# Out:
# user_score         9123
# critic_score       8576
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# rating                0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 1.5. Memperbaiki Tipe Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16713 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Data pada kolom `year_of_release` diubah menjadi integer.

# %%
# Change the year_of_release type to integer
data['year_of_release'] = data['year_of_release'].astype(int)

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 1.6. Memperbaiki Kualitas Data

# %% [markdown]
# Menambahkan kolom total sales.

# %%
# Sumarize the total sales
sales = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales']
data['total_sales'] = data[sales].sum(axis=1)

# %%
data.sample(5)
# Out:
#                                                 name platform  \
# 6061                               Warriors Orochi 2      PSP
# 2265                                    Street Hoops      PS2
# 11331                  Deadliest Catch: Sea of Chaos      PS3
# 3235   LEGO Pirates of the Caribbean: The Video Game      3DS
# 5890                Pride FC: Fighting Championships      PS2
#
#        year_of_release     genre  na_sales  eu_sales  jp_sales  other_sales  \
# 6061              2008    Action      0.06      0.00      0.22         0.01
# 2265              2002    Sports      0.45      0.35      0.00         0.12
# 11331             2010    Sports      0.08      0.00      0.00         0.01
# 3235              2011    Action      0.29      0.27      0.00         0.06
# 5890              2003  Fighting      0.15      0.11      0.00         0.04
#
#        critic_score  user_score        rating  total_sales
# 6061           56.0         7.5             T         0.29
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ## 2. Analisis Data Exploratif (EDA)

# %% [markdown]
# ### 2.1. Memeriksa Data yang Sudah Bersih

# %%
# Check general data_new info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int32
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16713 non-null  object
#  11  total_sales      16713 non-null  float64
# dtypes: float64(7), int32(1), object(4)
# memory usage: 1.5+ MB

# %%
# Calculating some statistical data
data.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16713.000000  16713.000000  16713.000000  16713.000000
# mean       2006.474960      0.263302      0.145045      0.077625
# std           5.896089      0.813565      0.503359      0.308871
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score   user_score   total_sales
# count  16713.000000   8137.000000  7590.000000  16713.000000
# mean       0.047343     68.967679     7.125046      0.533315
# std        0.186742     13.938165     1.500006      1.548282
# min        0.000000     13.000000     0.000000      0.000000
# 25%        0.000000     60.000000     6.400000      0.060000
# ...

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Data sales terdapat penjualan minimum 0, kemungkinan nilai tersebut akibat game tidak laku terjual atau belum terjual. Beberapa nilai sales terdapat penjualan 0 pada kuartil bawah. Bahkan pada jp_sales median sales yaitu 0.

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 2.2. Mempelajari Parameter Inti

# %% [markdown]
# Untuk mempelajari outlier memengaruhi bentuk dan kemudahan pembacaan analisis, dilakukan pendekatan kepada beberapa parameter berikut:
#
# - Tahun rilis,
# - platform yang digunakan, dan
# - genre game

# %% [markdown]
# Berikut beberapa pertanyaan-pertanyaan dasar untuk memeriksa keakuratan data:
#
# * Berapa jumlah game yang tercatat dalam data?
# * Berapa banyak platform yang diamati?
# * Dari rentang tahun berapa data tercatat?
# * Berapa jumlah game yang rilis per tahunnya?
# * Genre mana yang paling banyak?

# %%
# Ansewering basic question
print('Jawaban pertanyaan dasar tersebut yaitu:')
total_game_release = data.shape[0]
print('Jumlah game dirilis:', total_game_release)
total_platform = len(data['platform'].unique())
print('Jumlah platform:', total_platform)
print('Rentang tahun data diambil:', data['year_of_release'].min(),'hingga', data['year_of_release'].max())
print('Jumlah game dirilis per tahun:', data['year_of_release'].value_counts().head(5))
print('Genre paling banyak yaitu:',data['genre'].value_counts().head(3))
# Out:
# Jawaban pertanyaan dasar tersebut yaitu:
# Jumlah game dirilis: 16713
# Jumlah platform: 31
# Rentang tahun data diambil: 1980 hingga 2016
# Jumlah game dirilis per tahun: 2009    1476
# 2008    1457
# 2010    1302
# 2007    1197
# 2011    1161
# Name: year_of_release, dtype: int64
# Genre paling banyak yaitu: Action    3369
# Sports    2348
# Misc      1750
# Name: genre, dtype: int64

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Game dirilis dari tahun 1980-2016 dengan 2008 memiliki jumlah game tertinggi.
# * Terdapat 31 platform yang ada.
# * Genre yang paling banyak beredar yaitu game bergenre Action.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - akan lebih baik jika bisa diplot
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak, terimakasih sarannya. Tapi saya sudah membuat plot yang serupa di bawah. Atau mungkin Kak Adipta bisa menjelaskan seperti apa yang di plot? saya masih kurang paham.
# </div>

# %% [markdown]
# Pemeriksaan selanjutnya akan menggunakan diagram data. Setiap batang atau bar yang ada pada diagram merepresentasikan sebuah nilai: semakin tinggi nilainya, semakin tinggi pula batangnya. Perbedaan antar nilai dapat terlihat dengan jelas.

# %%
# Getting some data
data[['platform', 'year_of_release', 'genre']]
# Out:
#       platform  year_of_release         genre
# 0          Wii             2006        Sports
# 1          NES             1985      Platform
# 2          Wii             2008        Racing
# 3          Wii             2009        Sports
# 4           GB             1996  Role-Playing
# ...        ...              ...           ...
# 16708      PS3             2016        Action
# 16709     X360             2006        Sports
# 16710      PSV             2016     Adventure
# 16711      GBA             2003      Platform
# 16712      PSV             2016    Simulation
#
# [16713 rows x 3 columns]

# %% [markdown]
# Kolom `platform`, `year_of_release`, `genre` memiliki variabel katagorik. Maka diagram batang dapat digunakan.

# %%
category_column = ['platform', 'year_of_release', 'genre']

# Loop through the column names
for column in category_column:

    # Create a bar plot with the counts of each category in the column
    plt.figure(figsize=(10, 10))
    sns.countplot(x=column, data=data)

    # Add x-axis label
    plt.xlabel(column)
    plt.xticks(rotation=45)

    # Add y-axis label
    plt.ylabel('Jumlah game yang dirilis')

    plt.show()

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Secara diagram histogram, terlihat bahwa perkembangan game dirilis mengalami peningkatan dan tertinggi yaitu pada tahun 2008.
# * Platform game yang memiliki game yang telah dirilis terbanyak yaitu DS dan PS2.
# * Jenis game yang paling banyak dirilis yaitu game bergenre Action

# %% [markdown]
# <div class="alert alert-warning">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - gambarnya kalau bisa diperlebar akan lebih baik
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak, sudah diperbesar.
# </div>

# %% [markdown]
# ### 2.3. Penjualan Berdasarkan Platform

# %%
# Checking platform with most sales
platform_sales = data.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(by='total_sales',ascending=False)
platform_sales.reset_index().head()
# Out:
#   platform  total_sales
# 0      PS2      1255.77
# 1     X360       971.42
# 2      PS3       939.65
# 3      Wii       907.51
# 4       DS       806.12

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Berdasarkan total penjualan, game di platform PS2 memiliki total penjualan tertinggi yaitu 1255.77 juta USD.

# %% [markdown]
# **Analisa** distribusi PS2

# %%
# Query PS2
platform_ps2 = data.query('platform in ("PS2")')
platform_ps2
# Out:
#                                                    name platform  \
# 17                        Grand Theft Auto: San Andreas      PS2
# 24                          Grand Theft Auto: Vice City      PS2
# 28                               Gran Turismo 3: A-Spec      PS2
# 38                                 Grand Theft Auto III      PS2
# 48                                       Gran Turismo 4      PS2
# ...                                                 ...      ...
# 16668      Sugar + Spice! Anoko no Suteki na Nanimokamo      PS2
# 16669                                    Kanokon: Esuii      PS2
# 16681                  Scarlett: Nichijou no Kyoukaisen      PS2
# 16687                                         Real Rode      PS2
# 16707  SCORE International Baja 1000: The Official Game      PS2
#
#        year_of_release      genre  na_sales  eu_sales  jp_sales  other_sales  \
# 17                2004     Action      9.43      0.40      0.41        10.57
# ...

# %%
# Calculate total sales of PS2 per year
platform_ps2.groupby('year_of_release')['total_sales'].sum().reset_index().sort_values(by='total_sales', ascending=False)
# Out:
#     year_of_release  total_sales
# 4              2004       211.81
# 2              2002       205.38
# 3              2003       184.31
# 5              2005       182.87
# 1              2001       166.43
# 6              2006       103.42
# 7              2007        75.99
# 8              2008        53.90
# 0              2000        39.17
# 9              2009        26.40
# 10             2010         5.64
# 11             2011         0.45

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Berdasarkan total penjualan game di platform PS2, tahun 2004 memiliki total penjualan tertinggi yaitu 211.81 juta USD.
# * Walaupun tertinggi, namun penjualan PS2 hanya dari tahun 2000 hingga tahun 2011. Sedangkan 2012-2016 tidak ada penjualan game.

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# **Analisa** distribusi X360 dan PS3

# %%
# Query X360
platform_x360 = data.query('platform in ("X360")')
platform_x360
# Out:
#                                   name platform  year_of_release     genre  \
# 14                  Kinect Adventures!     X360             2010      Misc
# 23                  Grand Theft Auto V     X360             2013    Action
# 29      Call of Duty: Modern Warfare 3     X360             2011   Shooter
# 32             Call of Duty: Black Ops     X360             2010   Shooter
# 35          Call of Duty: Black Ops II     X360             2012   Shooter
# ...                                ...      ...              ...       ...
# 16611         Dragon Ball Z for Kinect     X360             2012  Fighting
# 16620  World Snooker Championship 2007     X360             2007    Sports
# 16645      Metal Gear Solid HD Edition     X360             2011    Action
# 16652               Ben 10 Omniverse 2     X360             2013    Action
# 16709                 LMA Manager 2007     X360             2006    Sports
#
# ...

# %%
# Calculate total sales of X360 per year
platform_x360.groupby('year_of_release')['total_sales'].sum().reset_index().sort_values(by='total_sales', ascending=False)
# Out:
#     year_of_release  total_sales
# 5              2010       180.21
# 6              2011       143.84
# 3              2008       135.26
# 4              2009       120.29
# 7              2012        99.74
# 2              2007        95.41
# 8              2013        88.58
# 1              2006        51.62
# 9              2014        34.74
# 10             2015        11.96
# 0              2005         8.25
# 11             2016         1.52

# %%
# Query PS3
platform_ps3 = data.query('platform in ("PS3")')
platform_ps3
# Out:
#                                           name platform  year_of_release  \
# 16                          Grand Theft Auto V      PS3             2013
# 34                  Call of Duty: Black Ops II      PS3             2012
# 37              Call of Duty: Modern Warfare 3      PS3             2011
# 41                     Call of Duty: Black Ops      PS3             2010
# 54                              Gran Turismo 5      PS3             2010
# ...                                        ...      ...              ...
# 16637  WSC REAL 09: World Snooker Championship      PS3             2009
# 16672            Tsukigime Ranko's Longest Day      PS3             2014
# 16674                         G1 Jockey 4 2008      PS3             2008
# 16689             Dynasty Warriors: Eiketsuden      PS3             2016
# 16708            Samurai Warriors: Sanada Maru      PS3             2016
#
#          genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %%
# Calculate total sales of PS3 per year
platform_ps3.groupby('year_of_release')['total_sales'].sum().reset_index().sort_values(by='total_sales', ascending=False)
# Out:
#     year_of_release  total_sales
# 5              2011       165.09
# 4              2010       142.17
# 3              2009       130.93
# 2              2008       118.52
# 7              2013       113.25
# 6              2012       107.36
# 1              2007        73.19
# 8              2014        47.76
# 0              2006        20.96
# 9              2015        16.82
# 10             2016         3.60

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Setelah dilakukan analisis distribusi pada platform terbaru yaitu X360 dan PS3, platform tersebut juga menempati posisi ke 2 dan ke 3 terbesar. Penjualan X360 dari tahun 2005-2016 dan 2006-2016 untuk PS3.
# * Berdasarkan total penjualan game di platform X360, tahun 2010 memiliki total penjualan tertinggi yaitu 170.03 juta USD. Sedangkan pada tahun 2016 mendapatkan penjualan game hanya 1.52 juta USD.
# * Berdasarkan total penjualan game di platform PS2, tahun 2011 memiliki total penjualan tertinggi yaitu 156.78 juta USD. Sedangkan pada tahun 2016 mendapatkan penjualan game hanya 3.60 juta USD.
# * Melihat perbandingan distribusi data tersebut, platform PS2 mulai dilupakkan dan digantikan oleh X360 dan PS3.

# %% [markdown]
# **Kesimpulan:**
#
# * Walaupun penjualan PS2 merupakan penjualan tertinggi dari keseluruhan penjualan, namun penjualan ini berhenti pada tahun 2011.
# * Jika dilihat dari tahun game pertama dirilis, perlu 5-6 tahun waktu yang dibutuhkan platform baru untuk muncul.
# * Game pertama X360 dirilis pada tahun 2005 dan game pertama PS3 dirilis pada tahun 2006. Perlu waktu sekitar 7 tahun (2005-2011) untuk membuat PS2 memudar popularitasnya dan digantikan dengan platfrom lain yaitu X360. Sedangkan generasi penerusnya yaitu PS3 memerlukan waktu 6 tahun (2006-2011).

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 2.4. Penjualan Terbanyak Pada Tahun 2013-2016

# %% [markdown]
# Berdasarkan analisa sebelumnya perlu waktu sekitar 12 tahun PS2 bertahan dan perlu waktu sekitar 6-7 tahun platform tersebut digantikan dengan platform baru hingga akhirnya dilupakan. Maka untuk kasus X360 atau PS3 kemungkinan sama akan terjadi, kemungkinan 12 tahun dari dirilis yaitu tahun 2017 platform tersebut akkan memudar popularitasnya. Maka diambil tahun 2013 sebagai pacuan awal.

# %%
# Creates a slice of rows where the year of release is 2013 and above 
new_data = data.query('year_of_release >= 2013')

# %%
# Checking platform with most sales
platform_sales_new = new_data.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(by='total_sales',ascending=False)
platform_sales_new.reset_index().head()
# Out:
#   platform  total_sales
# 0      PS4       314.14
# 1      PS3       181.43
# 2     XOne       159.32
# 3      3DS       144.44
# 4     X360       136.80

# %% [markdown]
# **Kesimpulan:**
#
# * Setelah dilakukan slice pada tahun 2013 hingga 2016, terbukti bahwa X360 sudah mulai menyusut dan diganti generasi baru yaitu XOne. Namun pada kasus ini penjualan pada platform PS3 masih diposisi ke 2 setelah PS4 yang memiliki penjualan tertinggi.
# * Penjualan pada platform PS4 cukup tinggi dengan penjualan 314.14 juta USD dibandungkan saingannya yaitu XOne yang hanya 159.32 juta USD. platform pada PS4 berpotensi menghasilkan keuntungan.

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 2.5. Penjualan Global Semua Game Berdasarkan Platform Pada Tahun 2013-2016

# %%
new_data.sample(3)
# Out:
#                            name platform  year_of_release   genre  na_sales  \
# 15941  Professional Farmer 2016      PS4             2015  Action      0.00
# 11816        Escape Dead Island      PS3             2014  Action      0.04
# 3536            Just Dance 2016     WiiU             2015    Misc      0.27
#
#        eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15941      0.01       0.0         0.00           NaN         NaN
# 11816      0.03       0.0         0.01          40.0         3.5
# 3536       0.25       0.0         0.05          73.0         6.9
#
#              rating  total_sales
# 15941  unidentified         0.01
# 11816             M         0.08
# 3536           E10+         0.57

# %%
# Create a boxplot using seaborn
plt.figure(figsize=(10,10))
sns.boxplot(x='platform', y='total_sales', data=new_data)
plt.grid(True)
plt.show()

# %%
# Pivot table about avg game platform total sales
avg_platform_sales = new_data.pivot_table(values='total_sales', 
                                       index='platform',
                                       aggfunc=['mean', 'count'])
avg_platform_sales.columns = ['avg_sales', 'total_game']

# %%
avg_platform_sales.sort_values('avg_sales', ascending=False)
# Out:
#           avg_sales  total_game
# platform
# PS4        0.801378         392
# X360       0.735484         186
# XOne       0.645020         247
# Wii        0.593913          23
# WiiU       0.562000         115
# PS3        0.525884         345
# 3DS        0.464437         311
# PC         0.208624         189
# DS         0.192500           8
# PSV        0.092618         359
# PSP        0.052239          67

# %% [markdown]
# **Kesimpulan:**
#
# * Ditinjau dari grafik boxplot, tidak ada perbedaan drastis antara rata-rata penjualan. Data secara statistik juga menunjukkan tidak ada perbedaan yang signifikan.
# * Rata-rata penjualan tertinggi yaitu platform PS4 dan memiliki jumlah game terbanyak juga yaitu 392.

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 2.6. Korelasi Penjualan dan Ulasan Pada Tahun 2013-2016

# %%
# Filter to PS4 only
ps4_sales = new_data[new_data['platform'] == 'PS4']

# %%
# Scatterplot for critic score
sns.scatterplot(x="critic_score", y="total_sales", data=ps4_sales, color='#533A71')
plt.grid(True)
plt.show()

# %%
# Hexbinplot for critic score
sns.jointplot(x='critic_score', y='total_sales', data=ps4_sales, kind='hex', color='#533A71')
plt.grid(True)
plt.show()

# %%
# Scatterplot for user score
sns.scatterplot(x="user_score", y="total_sales", data=ps4_sales, color='#6184D8')
plt.xticks(rotation=55)
plt.grid(True)
plt.show()

# %%
# Hexbinplot for user score
sns.jointplot(x='user_score', y='total_sales', data=ps4_sales, kind='hex', color='#6184D8')
plt.grid(True)
plt.show()

# %%
# Correlation between total sales and critic score
ps4_sales['total_sales'].corr(ps4_sales['critic_score'])
# Out:
# 0.4065679020617816

# %%
# Correlation  between total sales and user score
ps4_sales['total_sales'].corr(ps4_sales['user_score'])
# Out:
# -0.031957110204556424

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Ditinjau dari grafik scatterlot dan hexbin, ulasan pengguna dan ulasan para profesional tidak terlalu bahkan sangat kecil dalam mempengaruhi total penjualan pada platform PS4. Korelasi yang ditunjukkan tampak mendekati 0.

# %% [markdown]
# PS4 akan dibandingkan dengan kompetitornya yaitu XOne.

# %%
# Filter to XOne only
xone_sales = new_data[new_data['platform'] == 'XOne']

# %%
# Scatterplot for critic score
sns.scatterplot(x="critic_score", y="total_sales", data=xone_sales, color='#439A86')
plt.grid(True)
plt.show()

# %%
# Hexbinplot for critic score
sns.jointplot(x='critic_score', y='total_sales', data=xone_sales, kind='hex', color='#439A86')
plt.grid(True)
plt.show()

# %%
# Scatterplot for user score
sns.scatterplot(x="user_score", y="total_sales", data=xone_sales, color='#007991')
plt.xticks(rotation=55)
plt.grid(True)
plt.show()

# %%
# Hexbinplot for user score
sns.jointplot(x='user_score', y='total_sales', data=xone_sales, kind='hex', color='#007991')
plt.grid(True)
plt.show()

# %%
# Correlation between total sales and critic score
xone_sales['total_sales'].corr(xone_sales['critic_score'])
# Out:
# 0.41699832800840164

# %%
# Correlation  between total sales and user score
xone_sales['total_sales'].corr(xone_sales['user_score'])
# Out:
# -0.06892505328279415

# %% [markdown]
# **Kesimpulan:**
#
# * Ditinjau dari grafik scatterlot dan hexbin, ulasan pengguna dan ulasan para profesional tidak terlalu bahkan sangat kecil dalam mempengaruhi total penjualan pada platform XOne. Korelasi yang ditunjukkan tampak mendekati 0.
# * Perbedaan PS4 dan XOne dalam ulasan pengguna atau profesional sama saja tidak ada korelasinya dalam total penjualan.

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# ### 2.7. Analisis Distribusi Game Berdasarkan Genre pada Tahun 2013-2016

# %%
top_genre = new_data['genre'].value_counts().sort_values(ascending=False)
top_genre.reset_index()
# Out:
#            index  genre
# 0         Action    767
# 1   Role-Playing    294
# 2      Adventure    246
# 3         Sports    215
# 4        Shooter    188
# 5           Misc    155
# 6         Racing     86
# 7       Fighting     80
# 8       Platform     74
# 9     Simulation     64
# 10      Strategy     56
# 11        Puzzle     17

# %%
# Create a bar plot
plt.figure(figsize=(10,10))
top_genre.plot.bar(color='#BCD8C1')
plt.title('Total Games by Genre 2013-2016')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - gambar bisa diperbesar akan lebih baik
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak, sudah diperbesar.
# </div>

# %% [markdown]
# **Kesimpulan sementara:**
#
# * Pada tahun 2013-2016, game dengan genre Action memiliki game yang telah dirilis terbanyak. Selanjutnya ada Role-Playing dan Adventure. Sedangkan game Puzzle hanya 17 game yang dirilis selama 4 tahun terakhir.

# %%
genre_sales = new_data.groupby('genre')['total_sales'].sum().sort_values(ascending=False)
genre_sales.reset_index()
# Out:
#            genre  total_sales
# 0         Action       322.27
# 1        Shooter       233.05
# 2         Sports       150.67
# 3   Role-Playing       146.18
# 4           Misc        62.82
# 5       Platform        42.63
# 6         Racing        39.98
# 7       Fighting        35.31
# 8      Adventure        23.73
# 9     Simulation        22.25
# 10      Strategy        10.08
# 11        Puzzle         3.17

# %%
# Create a bar plot
plt.figure(figsize=(10,10))
genre_sales.plot.bar(color='#222E50')
plt.title('Total Sales by Genre 2013-2016')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - gambar akan lebih baik jika diperbesar
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak, sudah diperbesar.
# </div>

# %% [markdown]
# **Kesimpulan:**
#
# * Genre yang paling menguntungkan pada tahun 2013-2016 adalah game dengan Genre Action. Selanjutnya ada Shooter (FPS).
# * Game bergenre Action memiliki total penjualan sebesar 321.87 juta USD dengan penjualan sebanyak 766 game. Walaupun game bergenre Role-Playing mempunyai game terbanyak kedua yaitu sebesar 292 game, namun tidak memiliki penjualan tertinggi kedua, melainkan game bergenre Shooter. Sedangkan game bergenre Shooter memiliki 187 game tetapi menempati peringat kedua dalam penjualan, yaitu sebesar 232.98 juta USD
# * Game bergenre Shooter memiliki potensi dalam penjualan game, karena dengan unit yang tidak terlalu banyak namun total penjualan cukup tinggi.

# %% [markdown]
# ### 2.8. Profil Pengguna Wilayah (NA, EU, JP) Pada Tahun 2013-2016

# %% [markdown]
# **Berdasarkan Platform**

# %%
# User profile by platform in NA
profil_na = new_data.groupby('platform')['na_sales'].sum().reset_index().sort_values(by='na_sales', ascending=False)
profil_na['market_share'] = (profil_na['na_sales']/profil_na['na_sales'].sum()) * 100
profil_na.head()
# Out:
#    platform  na_sales  market_share
# 4       PS4    108.74     24.789131
# 10     XOne     93.12     21.228286
# 9      X360     81.66     18.615784
# 3       PS3     63.50     14.475904
# 0       3DS     39.04      8.899831

# %%
# Create a bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x='platform', y='na_sales', data=profil_na)
plt.title('User Profile in NA by Platform 2013-2016')
plt.xlabel('Platform')
plt.ylabel('NA Sales')
plt.show()

# %%
#  User profile by platform in EU
profil_eu = new_data.groupby('platform')['eu_sales'].sum().reset_index().sort_values(by='eu_sales', ascending=False)
profil_eu['market_share'] = (profil_eu['eu_sales']/profil_eu['eu_sales'].sum()) * 100
profil_eu.head()
# Out:
#    platform  eu_sales  market_share
# 4       PS4    141.09     35.947413
# 3       PS3     67.81     17.276873
# 10     XOne     51.59     13.144284
# 9      X360     42.52     10.833397
# 0       3DS     31.17      7.941604

# %%
# Create a bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x='platform', y='eu_sales', data=profil_eu)
plt.title('User Profile in EU by Platform 2013-2016')
plt.xlabel('Platform')
plt.ylabel('EU Sales')
plt.show()

# %%
# User profile by platform in JP
profil_jp = new_data.groupby('platform')['jp_sales'].sum().reset_index().sort_values(by='jp_sales', ascending=False)
profil_jp['market_share'] = (profil_jp['jp_sales']/profil_jp['jp_sales'].sum()) * 100
profil_jp.head()
# Out:
#   platform  jp_sales  market_share
# 0      3DS     67.86     48.161817
# 3      PS3     23.35     16.572037
# 6      PSV     18.66     13.243435
# 4      PS4     15.96     11.327182
# 8     WiiU     10.88      7.721789

# %%
# Create a bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x='platform', y='jp_sales', data=profil_jp)
plt.title('User Profile in JP by Platform 2013-2016')
plt.xlabel('Platform')
plt.ylabel('JP Sales')
plt.show()

# %% [markdown]
# **Kesimpulan:**
#
# * Wilayah NA, 5 platform teratas yaitu PS4, XOne, X360, PS3, dan 3DS.
# * WIlayah EU, 5 platform teratas yaitu PS4, PS3, XOne, X360, dan 3DS.
# * Wilayah JP, 5 platform teratas yaitu 3DS, PS3, PSV, PS4, dan WiiU.
# * Variasi pangsa pasar dari satu wilayah ke wilayah lainnya cukup berbeda. Pada kasus ini, penjualan PS4 pada wilayah NA yaitu 24.789131, sedangkan untuk wilayah EU lebih tinggi yaitu 35.947413. Namun di wilayah JP malah yang menjadi pusat pembuatannya hanya 11.327182. Di wilayah JP yang sangat tinggi yaitu 3DS, mungkin dikarenakan banyaknya game-game berbahasa jepang dan tidak ada terjemahan bahasa inggris.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - kalau diplot akan lebih baik
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak, sudah diplot.
# </div>

# %% [markdown]
# **Berdasarkan Genre**

# %%
# Function for user profile by genre in each area
def sales_genre_area(area):
    df = new_data.groupby('genre')[area].sum().reset_index().sort_values(by=area, ascending=False)
    df['market_share'] = df[area]/df[area].sum() * 100
    return df.head()

# %%
# User profile by platform in NA
check_na = sales_genre_area('na_sales')
check_na
# Out:
#            genre  na_sales  market_share
# 0         Action    126.23     28.776273
# 8        Shooter    109.78     25.026216
# 10        Sports     65.27     14.879405
# 7   Role-Playing     46.51     10.602745
# 3           Misc     27.49      6.266813

# %%
# Create a bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x='genre', y='na_sales', data=check_na)
plt.title('User Profile in NA by Genre 2013-2016')
plt.xlabel('Genre')
plt.ylabel('NA Sales')
plt.show()

# %%
# User profile by platform in EU
check_eu = sales_genre_area('eu_sales')
check_eu
# Out:
#            genre  eu_sales  market_share
# 0         Action    118.32     30.145991
# 8        Shooter     87.88     22.390379
# 10        Sports     60.52     15.419501
# 7   Role-Playing     37.02      9.432087
# 6         Racing     20.19      5.144080

# %%
# Create a bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x='genre', y='eu_sales', data=check_eu)
plt.title('User Profile in EU by Genre 2013-2016')
plt.xlabel('Genre')
plt.ylabel('EU Sales')
plt.show()

# %%
# User profile by platform in JP
check_jp = sales_genre_area('jp_sales')
check_jp
# Out:
#           genre  jp_sales  market_share
# 7  Role-Playing     51.14     36.295245
# 0        Action     40.49     28.736693
# 3          Misc      9.20      6.529454
# 2      Fighting      7.65      5.429383
# 8       Shooter      6.61      4.691270

# %%
# Create a bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x='genre', y='jp_sales', data=check_jp)
plt.title('User Profile in JP by Genre 2013-2016')
plt.xlabel('Genre')
plt.ylabel('JP Sales')
plt.show()

# %% [markdown]
# **Kesimpulan:**
#
# * Wilayah NA, 5 genre teratas yaitu Action, Shooter, Sports, Role-Playing, dan Misc.
# * WIlayah EU, 5 genre teratas yaitu Action, Shooter, Sports, Role-Playing, dan Racing.
# * Wilayah JP, 5 genre teratas yaitu Role-Playing, Action, Misc, Fighting, dan Shooter.
# * Variasi pangsa pasar dari satu wilayah ke wilayah lainnya cukup berbeda. Pada kasus ini, penjualan game bergenre action pada wilayah NA yaitu 28.776273, sedangkan untuk wilayah EU lebih tinggi yaitu 30.145991. Namun di wilayah JP game bergenre action 28.736693, hampir sama dengan di wilayah NA. Di wilayah JP yang sangat tinggi yaitu game bergenre Role-playing, yaitu 36.295245.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - kalau bisa diplot akan lebih baik
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak, sudah diplot.
# </div>

# %% [markdown]
# **Berdasarkan Rating**

# %% [markdown]
# Keterangan rating ESRB :
#
# * EC : Early Childhood (anak-anak dibawah umur)
# * E : Everyone (semua orang)
# * E10+ : Everyone (umur sepuluh tahun keatas)
# * T : Teen (umur 13 tahun keatas)
# * M : Mature (umur 17 tahun keatas)
# * K-A : Kids to Adults (anak-anak hingga dewasa)
# * AO : Adults Only (umur 18 tahun keatas)
# * RP : Rating Pending (masih dalam penundaan pihak ESRB)
# * unidentified : tidak teridentifikasi

# %%
# Function for user profile by genre in each area
def sales_rating_area(area):
    df_1 = new_data.groupby('rating')[area].sum().reset_index().sort_values(by=area, ascending=False)
    df_1['market_share'] = df_1[area]/df_1[area].sum() * 100
    return df_1.head()

# %%
# User profile by rating in NA
rating_na = sales_rating_area('na_sales')
rating_na
# Out:
#          rating  na_sales  market_share
# 2             M    165.21     37.662426
# 4  unidentified     89.70     20.448639
# 0             E     79.17     18.048147
# 1          E10+     54.50     12.424201
# 3             T     50.08     11.416587

# %%
# Create a bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x='rating', y='na_sales', data=rating_na)
plt.title('User Profile in NA by Rating 2013-2016')
plt.xlabel('Rating')
plt.ylabel('NA Sales')
plt.show()

# %%
# User profile by rating in EU
rating_eu = sales_rating_area('eu_sales')
rating_eu
# Out:
#          rating  eu_sales  market_share
# 2             M    145.32     37.025147
# 0             E     83.38     21.243853
# 4  unidentified     78.91     20.104971
# 1          E10+     42.88     10.925119
# 3             T     42.00     10.700910

# %%
# Create a bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x='rating', y='eu_sales', data=rating_eu)
plt.title('User Profile in EU by Rating 2013-2016')
plt.xlabel('Rating')
plt.ylabel('EU Sales')
plt.show()

# %%
# User profile by rating in JP
rating_jp = sales_rating_area('jp_sales')
rating_jp
# Out:
#          rating  jp_sales  market_share
# 4  unidentified     85.10     60.397445
# 3             T     20.66     14.662881
# 0             E     15.14     10.745209
# 2             M     14.11     10.014194
# 1          E10+      5.89      4.180270

# %%
# Create a bar plot
plt.figure(figsize=(10, 10))
sns.barplot(x='rating', y='jp_sales', data=rating_jp)
plt.title('User Profile in JP by Rating 2013-2016')
plt.xlabel('Rating')
plt.ylabel('JP Sales')
plt.show()

# %% [markdown]
# **Kesimpulan:**
#
# * Penjualan game dengan rating mature memiliki penjualan tertinggi pada wilayah NA dan EU. Namun pada penjualan di wilayah JP tidak teridentifikasi dan ini cukup besar perbandingannya dengan yang ke 2 yaitu Teen.
# * Kemungkinan besar penjualan dengan rating mempengaruhi karena dapat dilihat dari perbandingan market share tiap wilayah dan genre.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - kalau bisa diplot akan lebih baik
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak, sudah diplot.
# </div>

# %% [markdown]
# ## 3. Analisis Data Statistik (Hypothesis Testing)

# %% [markdown]
# ### 3.1. Menguji Hipotesis

# %% [markdown]
# **Hipotesis Pertama:**
#
# **Rata-rata rating pengguna platform Xbox One dan PC adalah sama.**

# %% [markdown]
# <div class="alert alert-danger">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - Belum membuat H0 dan H1
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak.
# </div>

# %% [markdown]
# Dalam uji variansi, jika rasio sampel dengan varians yang lebih besar dibandingkan dengan sample yang variansya lebih kecil <4, maka bisa kita assumsikan varians keduanya setara. Atau bisa menggunakan uji levene dimana H0 nya adalah kedua grup memiliki varians setara dan H1 nya adalah kedua grup memiliki varians yang berbeda. Jika di hasil levene test menunjukkan p-value < dari critical value (alpha) maka kita bisa menolak H0, dan sebaliknya.

# %% [markdown]
# Sebelum masuk ke analisis data hipotesis, nilai nan perlu di atasi terlebih dahulu. Karena saat menguji levene dan ttest akan terdeteksi nilai nan.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int32
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16713 non-null  object
#  11  total_sales      16713 non-null  float64
# dtypes: float64(7), int32(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# nan values akan di drop

# %%
# Drop the nan values in user_score
data = data.dropna(subset=['user_score'])

# %% [markdown]
# <div class="alert alert-danger">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - tidak perlu di replace dengan mean
#     - di drop saja yang nila na
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak.
# </div>

# %%
# Query XOne
platform_xone = data.query('platform in ("XOne")')
platform_xone
# Out:
#                                  name platform  year_of_release         genre  \
# 165                Grand Theft Auto V     XOne             2014        Action
# 179    Call of Duty: Advanced Warfare     XOne             2014       Shooter
# 242                 Halo 5: Guardians     XOne             2015       Shooter
# 270                         Fallout 4     XOne             2015  Role-Playing
# 373           Assassin's Creed: Unity     XOne             2014        Action
# ...                               ...      ...              ...           ...
# 16542     Assassin's Creed Chronicles     XOne             2016        Action
# 16595     Saints Row: Gat out of Hell     XOne             2015        Action
# 16628        Sébastien Loeb Rally Evo     XOne             2016        Racing
# 16641               Rugby Challenge 3     XOne             2016        Sports
# 16658                Prison Architect     XOne             2016        Action
#
# ...

# %%
# Query PC
platform_pc = data.query('platform in ("PC")')
platform_pc
# Out:
#                                     name platform  year_of_release  \
# 85                            The Sims 3       PC             2009
# 138                    World of Warcraft       PC             2004
# 192                           Diablo III       PC             2012
# 218       StarCraft II: Wings of Liberty       PC             2010
# 284                            Half-Life       PC             1997
# ...                                  ...      ...              ...
# 16679                            Worms 2       PC             1997
# 16690  Metal Gear Solid V: Ground Zeroes       PC             2014
# 16694                             Breach       PC             2011
# 16700            STORM: Frontline Nation       PC             2011
# 16703                            15 Days       PC             2009
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 85       Simulation      0.99      6.42      0.00         0.60          86.0
# ...

# %%
# Create a sample for levene test
sample_1 = platform_xone['user_score']
sample_2 = platform_pc['user_score']

# %%
# Levene test
st.levene(sample_1, sample_2)
# Out:
# LeveneResult(statistic=1.2212506384014863, pvalue=0.2693951512047048)

# %% [markdown]
# Dikarenakan p-value > dari critical value (alpha = 0.05) maka kita tidak bisa menolak H0 dan kedua sampel dianggap memiliki varians yang sama (equal_var = True)

# %% [markdown]
# * H0 (Null Hypothesis) : Rata-rata rating pengguna platform Xbox One dan PC adalah sama.
# * H1 (Alternative Hypothesis) : Rata-rata rating pengguna platform Xbox One dan PC adalah berbeda.

# %%
# ttest_ind for sample 1 and 2
alpha = 0.05

results = st.ttest_ind(sample_1, sample_2, equal_var=True)

print('p-value: ', results.pvalue)

if results.pvalue < alpha:
    print("Kita menolak hipotesis nol")
else:
    print("Kita tidak dapat menolak hipotesis nol")
# Out:
# p-value:  1.3896435533548819e-05
# Kita menolak hipotesis nol

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# **Hipotesis Kedua:**
#
# **Rata-rata rating pengguna genre Action dan Sports berbeda.**

# %% [markdown]
# <div class="alert alert-danger">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - Belum membuat H0 dan H1
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak.
# </div>

# %% [markdown]
# H0 nya adalah kedua grup memiliki varians setara dan H1 nya adalah kedua grup memiliki varians yang berbeda. Jika di hasil levene test menunjukkan p-value < dari critical value (alpha) maka kita bisa menolak H0, dan sebaliknya.

# %%
# Create a sample for levene test
sample_3 = data.loc[data['genre'] == 'Action', 'user_score']
sample_4 = data.loc[data['genre'] == 'Sports', 'user_score']

# %%
# Levene test
st.levene(sample_3, sample_4)
# Out:
# LeveneResult(statistic=14.132896085177192, pvalue=0.0001736640672727649)

# %% [markdown]
# Dikarenakan p-value < dari critical value (alpha = 0.05) maka kita bisa menolak H0 dan kedua sampel dianggap memiliki varians yang berbeda (equal_var = False)

# %% [markdown]
# * H0 (Null Hypothesis) : Rata-rata rating pengguna genre Action dan Sports sama.
# * H1 (Alternative Hypothesis) : Rata-rata rating pengguna genre Action dan Sports berbeda.

# %%
# ttest_ind for sample 3 and 4
alpha = 0.05

results = st.ttest_ind(sample_3, sample_4, equal_var=False)

print('p-value: ', results.pvalue)

if results.pvalue < alpha:
    print("Kita menolak hipotesis nol")
else:
    print("Kita tidak dapat menolak hipotesis nol")
# Out:
# p-value:  0.11483818791498286
# Kita tidak dapat menolak hipotesis nol

# %% [markdown]
# **Kesimpulan:**
#
# * Hasil yang didapat dari uji hipotesis pertama yaitu rata-rata rating pengguna platform Xbox One dan PC adalah sama adalah **TIDAK BENAR**.
# * Hasil yang didapat dari uji hipotesis kedua yaitu rata-rata rating pengguna genre Action dan Sports berbeda adalah **TIDAK BENAR**.

# %% [markdown]
# Selanjutnya akan diuji apakah hal tersebut berlaku terhadap data 2013-2016 atau tidak.

# %% [markdown]
# **Hipotesis Pertama 2013-2017:**
#
# **Rata-rata rating pengguna platform Xbox One dan PC adalah sama.**

# %% [markdown]
# <div class="alert alert-danger">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - Belum membuat H0 dan H1
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak.
# </div>

# %% [markdown]
# H0 nya adalah kedua grup memiliki varians setara dan H1 nya adalah kedua grup memiliki varians yang berbeda. Jika di hasil levene test menunjukkan p-value < dari critical value (alpha) maka kita bisa menolak H0, dan sebaliknya.

# %% [markdown]
# nan values diisi dengan rata-rata

# %%
fill_data = new_data.copy()

# %%
# Drop the missing values
fill_data = fill_data.dropna(subset=['user_score'])

# %% [markdown]
# <div class="alert alert-danger">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - tidak perlu di replace dengan mean
#     - di drop saja yang nila na
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak.
# </div>

# %%
# Query XOne 2013-2017
new_platform_xone = fill_data.query('platform in ("XOne")')
new_platform_xone
# Out:
#                                  name platform  year_of_release         genre  \
# 165                Grand Theft Auto V     XOne             2014        Action
# 179    Call of Duty: Advanced Warfare     XOne             2014       Shooter
# 242                 Halo 5: Guardians     XOne             2015       Shooter
# 270                         Fallout 4     XOne             2015  Role-Playing
# 373           Assassin's Creed: Unity     XOne             2014        Action
# ...                               ...      ...              ...           ...
# 16542     Assassin's Creed Chronicles     XOne             2016        Action
# 16595     Saints Row: Gat out of Hell     XOne             2015        Action
# 16628        Sébastien Loeb Rally Evo     XOne             2016        Racing
# 16641               Rugby Challenge 3     XOne             2016        Sports
# 16658                Prison Architect     XOne             2016        Action
#
# ...

# %%
# Query PC 2013-2017
new_platform_pc = fill_data.query('platform in ("PC")')
new_platform_pc
# Out:
#                                     name platform  year_of_release  \
# 458                           The Sims 4       PC             2014
# 1094    StarCraft II: Heart of the Swarm       PC             2013
# 1350                      SimCity (2013)       PC             2013
# 1436                       Battlefield 4       PC             2013
# 1529                           Fallout 4       PC             2015
# ...                                  ...      ...              ...
# 16454                  Fallout Anthology       PC             2015
# 16461                   TrackMania Turbo       PC             2016
# 16507                             Ride 2       PC             2016
# 16516               Rugby World Cup 2015       PC             2015
# 16690  Metal Gear Solid V: Ground Zeroes       PC             2014
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 458      Simulation      1.00      1.82       0.0         0.23          70.0
# ...

# %%
# Create a sample for levene test
sample_5 = new_platform_xone['user_score']
sample_6 = new_platform_pc['user_score']

# %%
# Levene test
st.levene(sample_5, sample_6)
# Out:
# LeveneResult(statistic=8.44812129543499, pvalue=0.0038975531101303022)

# %% [markdown]
# Dikarenakan p-value < dari critical value (alpha = 0.05) maka kita tida bisa menolak H0 dan kedua sampel dianggap memiliki varians yang berbeda (equal_var = False)

# %% [markdown]
# * H0 (Null Hypothesis) : Rata-rata rating pengguna platform Xbox One dan PC adalah sama.
# * H1 (Alternative Hypothesis) : Rata-rata rating pengguna platform Xbox One dan PC adalah berbeda.

# %%
# ttest_ind for sample 5 and 6
alpha = 0.05

results = st.ttest_ind(sample_5, sample_6, equal_var=False)

print('p-value: ', results.pvalue)

if results.pvalue < alpha:
    print("Kita menolak hipotesis nol")
else:
    print("Kita tidak dapat menolak hipotesis nol")
# Out:
# p-value:  0.14759594013430463
# Kita tidak dapat menolak hipotesis nol

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# **Hipotesis Kedua 2013-2017:**
#
# **Rata-rata rating pengguna genre Action dan Sports berbeda.**

# %% [markdown]
# <div class="alert alert-danger">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# - Belum membuat H0 dan H1
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak.
# </div>

# %% [markdown]
# H0 nya adalah kedua grup memiliki varians setara dan H1 nya adalah kedua grup memiliki varians yang berbeda. Jika di hasil levene test menunjukkan p-value < dari critical value (alpha) maka kita bisa menolak H0, dan sebaliknya.

# %%
# Create a sample for levene test
sample_7 = fill_data.loc[fill_data['genre'] == 'Action', 'user_score']
sample_8 = fill_data.loc[fill_data['genre'] == 'Sports', 'user_score']

# %%
# Levene test
st.levene(sample_7, sample_8)
# Out:
# LeveneResult(statistic=26.375781745225087, pvalue=3.9119413036239563e-07)

# %% [markdown]
# Dikarenakan p-value < dari critical value (alpha = 0.05) maka kita bisa menolak H0 dan kedua sampel dianggap memiliki varians yang berbeda (equal_var = False)

# %% [markdown]
# * H0 (Null Hypothesis) : Rata-rata rating pengguna genre Action dan Sports sama.
# * H1 (Alternative Hypothesis) : Rata-rata rating pengguna genre Action dan Sports berbeda.

# %%
# ttest_ind for sample 7 and 8
alpha = 0.05

results = st.ttest_ind(sample_7, sample_8, equal_var=False)

print('p-value: ', results.pvalue)

if results.pvalue < alpha:
    print("Kita menolak hipotesis nol")
else:
    print("Kita tidak dapat menolak hipotesis nol")
# Out:
# p-value:  1.4711831608728666e-20
# Kita menolak hipotesis nol

# %% [markdown]
# <div class="alert alert-success">
# <b>Adipta's comment v.1</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>

# %% [markdown]
# **Kesimpulan:**
#
# * Hasil yang didapat dari uji hipotesis pertama yaitu rata-rata rating pengguna platform Xbox One dan PC adalah sama adalah **BENAR**, namun pada tahun 2013-2017.
# * Hasil yang didapat dari uji hipotesis kedua yaitu rata-rata rating pengguna genre Action dan Sports berbeda adalah **BENAR**, namun pada tahun 2013-2017.

# %% [markdown]
# ## Kesimpulan Umum

# %% [markdown]
# #### A. Pra-pemrosesan
#
# Dari eksplorasi pra-pemrosesan data, dapat disimpulkan bahwa:
# 1. Dataframe menyangkut data penjualan game tiap wilayah berdasaran platform. Missing value cukup tinggi terutama pada kolom user_score yang mempengaruhi dalam uji hipotesis.
# 2. Duplikat tidak ditemukan.
# 3. Telah dibuat perhitungan jumlah penjualan dari seluruh wilayah.
#
#
# #### B. Analisis Data Esksploratif (EDA)
#
# Dari hasil analisis data esksploratif, dapat disimpulkan bahwa:
# 1. Dataframe keseluruhan memiliki 16713 jumlah game dari tahun 1980 hingga 2016 dengan 31 jenis platform.
# 2. Diketahui jumlah game dirilis terbanyak yaitu pada tahun 2009. Setelahnya jumlah game mengalami penurunan.
# 3. Genre game yang paling banyak dirilis yaitu Action lalu Sports.
# 4. Lima platform dengan penjualan game terbanyak sepanjang tahun yaitu Platform PS2 lalu kemudian X360, PS3, Wii, dan DS.
# 5. Platform PS2 dengan total penjualan 1255.77 Juta USD, tahun 2004 merupakan penjualan tertinggi. Namun platform PS2 mengalami penurunan dan akhirnya dilupakan pada tahun 2012.
# 6. Jika dilihat dari tahun game pertama dirilis, perlu 5-6 tahun waktu yang dibutuhkan platform baru untuk muncul.
# 7. Jika dilihat dari popularitas sebuah platform, perlu waktu sekitar 6-7 tahun untuk membuat platform lama memudar popularitasnya dan digantikan dengan platfrom baru.
# 8. Berdasarkan analisis platform terkenal perlu waktu sekitar 12 tahun untuk bertahan. Untuk menganalisis prediksi kedepannya, diambilah sampel tahun 2013-2016, dan terbukti platfrom terbarupun akan memudar. Sehingga pada tahun 2017 sangat memungkinkan sekali untuk platform PS3/X360 untuk memudar popularitasnya dan digantikan dengan platfrom baru.
# 8. Rata-rata penjualan game berdasarkan platform pada tahun 2013-2016 tidak ada perbedaan yang sangat signifikan dengan jumlah game terbanyak yaitu PS4.
# 9. Korelasi antara ulasan pengguna/profesional sangat kecil bahkan tidak terlalu mempengaruhi penjualan pada platform pada tahun 2013-2016.
# 10. Genre game yang paling menguntungan pada tahun 2013-2016 adalah game bergenre Action, namun dengan penjualan game yang cukup banyak juga. Sedangkan game bergenre Shooter memiliki potensi penjualan game yang lebih tinggi dari Action, karena hanya menjual game yang tidak sebanyak game bergenre Action namun menempati urutas penjualan game paling menguntungkan kedua.
# 11. Profil pengguna tiap wilayah pada tahun 2013-2016 memiliki cukup perbedaan. Seperti pada NA dan EU, mereka lebih suka bermain pada PS4 dibandingkan JP pada 3DS. Sedangkan berdasarkan genre, wilayah NA dan EU menyukai game bergenre Action dibandingan JP bergenre Role-Playing. Untuk kasus rating, NA dan EU menyukai game dengan rating mature. Pada kasus rating di JP, rating tertinggi yaitu unidentified. Maka perlu dipertimbangkan untuk mengechek rating ini.
#
# #### C. Analisis Data Statistik (Hypothesis Testing)
#
# Dari hasil analisis pengujian hipotesis, dapat disimpulkan bahwa:
# 1. Hasil yang didapat dari uji hipotesis pertama yaitu rata-rata rating pengguna platform Xbox One dan PC adalah sama adalah tidak benar. Untuk hasil yang didapat dari uji hipotesis kedua yaitu rata-rata rating pengguna genre Action dan Sports berbeda adalah tidak benar.
# 2. Pada tahun 2013-2016, memiliki pendapat yang berbeda. Dengan pemfiltertan pada tahun 2013-2016, uji hipotesis pertama yaitu rata-rata rating pengguna platform Xbox One dan PC adalah sama adalah benar dan hasil yang didapat dari uji hipotesis kedua yaitu rata-rata rating pengguna genre Action dan Sports berbeda adalah benar.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# # General comments #1
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Good Job Kak! Sebagian besar kamu telah menyelesaikan project ini dengan baik Namun masih ada beberapa hal yang bisa diimprove yang saya tandai dengan comment berwarna kuning dan merah. Jika kamu telah merevisinya, projectmu akan di approve dan kamu bisa lanjut ke tahapan selanjutnya!.
#
# Keep going Kak, you are doing very well!
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
#
# Baik kak. Sudah di revisi..
# </div>
